# %%
! chmod 755 q; chmod 755 run_gpu.sh;if [ -x "$(command -v qsub)" ]; then ./q run_gpu.sh; else ./run_gpu.sh; fi
# Out:
# Job has been submitted to Intel(R) DevCloud and will execute soon.
#
# Job ID                    Name             User            Time Use S Queue
# ------------------------- ---------------- --------------- -------- - -----
# 2490499.v-qsvr-1           ...ub-singleuser u200671         00:00:14 R jupyterhub
# 2490503.v-qsvr-1           run_gpu.sh       u200671                0 Q batch
#
# Waiting for Output ████████████████████ Done⬇
#
# ########################################################################
# #      Date:           Fri Feb 16 04:21:38 PM PST 2024
# #    Job ID:           2490503.v-qsvr-1.aidevcloud
# #      User:           u200671
# # Resources:           cput=75:00:00,neednodes=1:gpu:ppn=2,nodes=1:gpu:ppn=2,walltime=06:00:00
# ########################################################################
#
# ## u200671 Se está compilando la búsqueda de caminos más cortos entre pares en paralelo- 1 of 7 gpu_practice.cpp
# ...
